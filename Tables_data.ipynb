# %%
import pandas as pd
import os

# %%
#load csv 
data = "C:/Users/owner/Desktop/Class Folder/Challenge/access/raw_data/new_cleaned.csv"
data_df = pd.read_csv(data)

# %%
data_df.head()
# Out:
#    Total  One or more types of computing devices  Desktop/laptop  \
# 0  83501                                   77443           62729
# 1  44264                                   38768           30768
# 2  30323                                   26269           19117
# 3  26462                                   22675           15879
# 4  30155                                   26120           21528
#
#    Only Desktop/laptop  Smartphone  Only Smartphone  Tablet/portable  \
# 0                 4403       70185             9358            53266
# 1                 3054       32921             3865            25422
# 2                  654       24088             3948            17024
# 3                 1440       20442             4172            13094
# 4                  599       24958             2809            19449
#
#    Only Tablet/portable  Other computing device  Only other  ...  \
# 0                  1100                    1184           0  ...
# ...

# %%
data_df.count()
# Out:
# Total                                                838
# One or more types of computing devices               838
# Desktop/laptop                                       838
# Only Desktop/laptop                                  838
# Smartphone                                           838
# Only Smartphone                                      838
# Tablet/portable                                      838
# Only Tablet/portable                                 838
# Other computing device                               838
# Only other                                           838
# No computer                                          838
# >10K                                                 836
# > $10k With Internet subscription                    838
# > $10k!!Without an Internet subscription             836
# Total!!$10k to $19.9k                                836
# $10k to $19.9k!!With Internet subscription           838
# ...

# %%
## UNDER 10K WITH/OUT INTERNET AND COMP DEVICE

# %%
pd.read_csv((data), usecols=['> $10k With Internet subscription ','One or more types of computing devices', '> $10k!!Without an Internet subscription'], nrows=836)under_tenk = 
under_tenk
# Out:
#      One or more types of computing devices  \
# 0                                     77443
# 1                                     38768
# 2                                     26269
# 3                                     22675
# 4                                     26120
# ..                                      ...
# 831                                   23102
# 832                                   24805
# 833                                   36068
# 834                                   91339
# 835                                   18109
#
#     > $10k With Internet subscription   \
# 0                                 3418
# 1                                 2831
# 2                                 1026
# 3                                 1864
# 4                                 1166
# ..                                 ...
# 831                               2124
# 832                               8453
# 833                               8408
# ...

# %%
## $10k to  $19.9k!!With/OUT an Internet subscription AND COMP DEVICE

# %%
ten_twentyk = pd.read_csv((data), usecols=['$10k to $19.9k!!With Internet subscription ','One or more types of computing devices', '$10k to  $19.9k!!Without an Internet subscription' ], nrows=836)
ten_twentyk
# Out:
#      One or more types of computing devices  \
# 0                                     77443
# 1                                     38768
# 2                                     26269
# 3                                     22675
# 4                                     26120
# ..                                      ...
# 831                                   23102
# 832                                   24805
# 833                                   36068
# 834                                   91339
# 835                                   18109
#
#     $10k to $19.9k!!With Internet subscription   \
# 0                                          3893
# 1                                          3329
# 2                                          2994
# 3                                          1989
# 4                                          1742
# ..                                          ...
# 831                                        2583
# ...

# %%
## $20k to $34.9k!!With/OUT an Internet subscription AND COMP DEVICE

# %%
twenty_thirty5k = pd.read_csv((data), usecols=['$20k to $34.9k!!With Internet subscription','One or more types of computing devices', '$20k to $34.9k!!Without an Internet subscription' ], nrows=836)
twenty_thirty5k
# Out:
#      One or more types of computing devices  \
# 0                                     77443
# 1                                     38768
# 2                                     26269
# 3                                     22675
# 4                                     26120
# ..                                      ...
# 831                                   23102
# 832                                   24805
# 833                                   36068
# 834                                   91339
# 835                                   18109
#
#     $20k to $34.9k!!With Internet subscription  \
# 0                                        12249
# 1                                         5543
# 2                                         4176
# 3                                         3955
# 4                                         2486
# ..                                         ...
# 831                                       3180
# ...

# %%
## $35k to $49.9k!!With/OUT Internet subscription AND COMP DEVICE

# %%
 thirty5_fortyk = pd.read_csv((data), usecols=['$35k to $49.9k!!With Internet subscription','One or more types of computing devices', '$35k to $49.9k!!Without an Internet subscription' ], nrows=836)
 thirty5_fortyk
# Out:
#      One or more types of computing devices  \
# 0                                     77443
# 1                                     38768
# 2                                     26269
# 3                                     22675
# 4                                     26120
# ..                                      ...
# 831                                   23102
# 832                                   24805
# 833                                   36068
# 834                                   91339
# 835                                   18109
#
#     $35k to $49.9k!!With Internet subscription  \
# 0                                         9207
# 1                                         3431
# 2                                         4153
# 3                                         2803
# 4                                         2953
# ..                                         ...
# 831                                       2854
# ...

# %%
## $50k to $74..9k!!With/OUT an Internet subscription AND COMP DEVICE

# %%
fifty_seventy5k = pd.read_csv((data), usecols=['$50k to $74,999!!With Internet subscription','One or more types of computing devices', '$50k to $74..9k!!Without an Internet subscription' ], nrows=836)
fifty_seventy5k
# Out:
#      One or more types of computing devices  \
# 0                                     77443
# 1                                     38768
# 2                                     26269
# 3                                     22675
# 4                                     26120
# ..                                      ...
# 831                                   23102
# 832                                   24805
# 833                                   36068
# 834                                   91339
# 835                                   18109
#
#     $50k to $74,999!!With Internet subscription  \
# 0                                         13211
# 1                                          7563
# 2                                          4470
# 3                                          3891
# 4                                          5863
# ..                                          ...
# 831                                        3888
# ...

# %%
## >$75,000!!With/OUT an Internet subscription AND COMP DEVICE

# %%
over_seventy5k = pd.read_csv((data), usecols=['>$75k!!With Internet subscription ','One or more types of computing devices', '>$75,000!!Without an Internet subscription' ], nrows=836)
over_seventy5k
# Out:
#      One or more types of computing devices  \
# 0                                     77443
# 1                                     38768
# 2                                     26269
# 3                                     22675
# 4                                     26120
# ..                                      ...
# 831                                   23102
# 832                                   24805
# 833                                   36068
# 834                                   91339
# 835                                   18109
#
#     >$75k!!With Internet subscription   \
# 0                                29089
# 1                                11647
# 2                                 7684
# 3                                 6144
# 4                                10562
# ..                                 ...
# 831                               6244
# 832                               1652
# 833                               3275
# ...
